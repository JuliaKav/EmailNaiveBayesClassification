# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'

# %%
df=pd.read_json(DATA_JSON_FILE)

# %%
df.head()
# Out:
#                                              MESSAGE  CATEGORY  \
# 0  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...         1
# 1  1) Fight The Risk of Cancer!\n\nhttp://www.adc...         1
# 2  1) Fight The Risk of Cancer!\n\nhttp://www.adc...         1
# 3  ##############################################...         1
# 4  I thought you might like these:\n\n1) Slim Dow...         1
#
#                                 FILE_NAME
# 0  00001.7848dde101aa985090474a91ec93fcf0
# 1  00002.d94f1b97e48ed3b553b3508d116e6a09
# 2  00003.2ee33bc6eacdb11f38d052c44819ba6c
# 3  00004.eac8de8d759b7e74154f142194282724
# 4  00005.57696a39d7d84318ce497886896bf90d

# %%
vectorizer=CountVectorizer(stop_words='english')

# %%
all_features=vectorizer.fit_transform(df.MESSAGE)

# %%
type(all_features)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
all_features
# Out:
# <3000x62660 sparse matrix of type '<class 'numpy.int64'>'
# 	with 324609 stored elements in Compressed Sparse Row format>

# %%
vectorizer.vocabulary_
# Out:
# {'doctype': 20340,
#  'html': 28718,
#  'public': 44355,
#  'w3c': 57215,
#  'dtd': 21042,
#  'transitional': 53871,
#  'en': 22240,
#  'head': 27743,
#  'meta': 36797,
#  'content': 17406,
#  '3d': 3669,
#  'text': 52883,
#  'charset': 15854,
#  '3dwindows': 3865,
#  '1252': 1193,
#  'http': 28729,
#  'equiv': 22634,
#  '3dcontent': 3777,
#  'ype': 60526,
#  'mshtml': 37853,
#  '00': 0,
#  '2314': 2507,
#  '1000': 878,
#  '3dgenerator': 3793,
#  'body': 13803,
#  'inserted': 30666,
#  'calypso': 15099,
#  'table': 52332,
#  'border': 13931,
#  '3d0': 3670,
#  'cellpadding': 15613,
#  'cellspacing': 15618,
#  '3d2': 3687,
#  'id': 29421,
#  '3d_calyprintheader_': 3751,
#  'ules': 54947,
#  '3dnone': 3822,
#  'style': 51374,
#  'color': 16796,
#  'black': 13489,
#  'display': 20019,
#  'width': 58286,
#  '100': 877,
#  'tbody': 52551,
#  'tr': 53774,
#  'td': 52600,
#  'colspan': 16809,
#  '3d3': 3701,
#  'hr': 28646,
#  '3dblack': 3768,
#  'noshade': 39376,
#  'size': 49831,
#  '3d1': 3672,
#  'end': 22294,
#  'font': 24672,
#  '000000': 3,
#  'face': 23579,
#  '3dverdana': 3861,
#  'arial': 11302,
#  'helvetica': 27883,
#  'br': 14084,
#  'ff0000': 24027,
#  'copperplate': 17552,
#  'gothic': 26577,
#  'bold': 13834,
#  '3d5': 3724,
#  'ptsize': 44330,
#  '10': 876,
#  'center': 15637,
#  'save': 48489,
#  '70': 6075,
#  'life': 34733,
#  'insurance': 30751,
#  'ff': 24023,
#  '0000': 2,
#  'spend': 50625,
#  'pt': 44295,
#  'quote': 45395,
#  'savings': 48499,
#  'align': 10401,
#  '3dleft': 3807,
#  'bordercolor': 13934,
#  '111111': 1059,
#  'wi': 58264,
#  'dth': 21044,
#  '3d650': 3737,
#  '35': 3455,
#  '3d4': 3713,
#  'ensurin': 22430,
#  'family': 23692,
#  'financial': 24239,
#  'security': 48943,
#  'important': 30201,
#  'ma': 35833,
#  'kes': 33069,
#  'buying': 14600,
#  'simple': 49726,
#  'affordable': 9796,
#  'provide': 44171,
#  'free': 25014,
#  'access': 9231,
#  'best': 13069,
#  'companies': 16943,
#  'lowest': 35333,
#  'rates': 45865,
#  '3dmiddle': 3811,
#  'valign': 56149,
#  '3dtop': 3855,
#  '18': 1609,
#  'padding': 41459,
#  'left': 34409,
#  '5px': 5364,
#  'right': 47249,
#  'fast': 23749,
#  'eas': 21542,
#  'saves': 48495,
#  'money': 37506,
#  'let': 34505,
#  'help': 27870,
#  'started': 50965,
#  'val': 56132,
#  'ues': 54745,
#  'country': 17695,
#  'new': 38850,
#  'coverage': 17730,
#  'hundreds': 28800,
#  'tho': 53097,
#  'usands': 55667,
#  'dollars': 20387,
#  'requesting': 46773,
#  'lifequote': 34744,
#  'service': 49169,
#  'minutes': 37146,
#  'complete': 17015,
#  'shop': 49505,
#  'compare': 16956,
#  'types': 54398,
#  'height': 27840,
#  '3d50': 3725,
#  '3dcenter': 3774,
#  'href': 28659,
#  'website': 58006,
#  'e365': 21387,
#  'cc': 15474,
#  'savequote': 48492,
#  'click': 16404,
#  'strong': 51309,
#  'protecting': 44132,
#  'investment': 31004,
#  'll': 35028,
#  'eve': 22944,
#  'make': 36032,
#  'sans': 48419,
#  'serif': 49139,
#  'receipt': 46142,
#  'email': 22119,
#  'error': 22707,
#  'wish': 58433,
#  'removed': 46617,
#  'list': 34887,
#  'mailto': 35989,
#  'coins': 16718,
#  'btamail': 14382,
#  'net': 38789,
#  'cn': 16577,
#  'type': 54393,
#  'remove': 46614,
#  'reside': 46836,
#  'state': 50992,
#  'prohibits': 44018,
#  'mail': 35954,
#  'solicitations': 50336,
#  'insuran': 30750,
#  'ce': 15571,
#  'disregard': 20038,
#  'fight': 24178,
#  'risk': 47300,
#  'cancer': 15146,
#  'www': 59000,
#  'adclick': 9478,
#  'ws': 58857,
#  'cfm': 15709,
#  '315': 3331,
#  'pk007': 42899,
#  'slim': 50009,
#  'guaranteed': 26984,
#  'lose': 35278,
#  '12': 1159,
#  'lbs': 34261,
#  '30': 3248,
#  'days': 18760,
#  '249': 2606,
#  'child': 15968,
#  'support': 51690,
#  'deserve': 19358,
#  'legal': 34419,
#  'advice': 9643,
#  '245': 2601,
#  'pk002': 42898,
#  'join': 32275,
#  'web': 57967,
#  'fastest': 23752,
#  'growing': 26877,
#  'singles': 49767,
#  'community': 16931,
#  '259': 2656,
#  'start': 50963,
#  'private': 43867,
#  'photo': 42633,
#  'album': 10353,
#  'online': 40504,
#  '283': 2795,
#  'wonderful': 58620,
#  'day': 18753,
#  'offer': 40218,
#  'manager': 36091,
#  'prizemama': 43886,
#  'leave': 34381,
#  'use': 55679,
#  'link': 34845,
#  'qves': 45416,
#  'com': 16822,
#  'trim': 54008,
#  'ilug': 30061,
#  'linux': 34863,
#  '7c17': 6379,
#  '7c114258': 6377,
#  'irish': 31191,
#  'users': 55708,
#  'group': 26867,
#  'mailman': 35981,
#  'listinfo': 34918,
#  'subscription': 51457,
#  'information': 30514,
#  'maintainer': 36016,
#  'listmaster': 34922,
#  'zzzz': 61813,
#  'spamassassin': 50500,
#  'taint': 52383,
#  'org': 40748,
#  '7c308417': 6383,
#  'adult': 9606,
#  'club': 16493,
#  'offers': 40225,
#  'membership': 36699,
#  'instant': 30714,
#  'sites': 49807,
#  'user': 55694,
#  'password': 41744,
#  '760382': 6234,
#  'internet': 30860,
#  'news': 38871,
#  '08': 434,
#  '02': 220,
#  'just': 32525,
#  'million': 37064,
#  'members': 36698,
#  'signed': 49674,
#  'month': 37544,
#  '721': 6137,
#  '184': 1634,
#  'faq': 23710,
#  'offering': 40223,
#  'advertisers': 9636,
#  'pay': 41824,
#  'ad': 9439,
#  'space': 50474,
#  'don': 20419,
#  'true': 54080,
#  'absolutely': 9134,
#  'cent': 15634,
#  'account': 9273,
#  'friends': 25094,
#  'yes': 60220,
#  'long': 35220,
#  'age': 9875,
#  'sign': 49666,
#  'following': 24655,
#  'links': 34854,
#  'member': 36697,
#  'multi': 37981,
#  'dollar': 20386,
#  'operations': 40602,
#  'policies': 43235,
#  'rules': 47892,
#  'required': 46776,
#  'info': 30498,
#  'won': 58617,
#  'charge': 15837,
#  'pass': 41718,
#  'believe': 12964,
#  'read': 46033,
#  'terms': 52826,
#  'conditions': 17141,
#  'adults': 9609,
#  'farm': 23724,
#  '80': 6630,
#  '71': 6107,
#  '66': 5656,
#  'aid': 10068,
#  'girls': 26237,
#  'animals': 10788,
#  'getting': 26053,
#  'freaky': 25007,
#  'lifetime': 34749,
#  'sexy': 49240,
#  'celebes': 15592,
#  'celebst': 15600,
#  'thousands': 53117,
#  'xxx': 59841,
#  'doing': 20376,
#  'play': 42995,
#  'house': 28574,
#  'porn': 43330,
#  'mega': 36662,
#  'live': 34954,
#  'feeds': 23938,
#  '60': 5508,
#  'cams': 15132,
#  'asian': 11459,
#  'sex': 49227,
#  'fantasies': 23704,
#  'japanese': 31786,
#  'schoolgirls': 48662,
#  'shows': 49560,
#  'lesbian': 34494,
#  'lace': 34042,
#  'jennifer': 31956,
#  'simpson': 49735,
#  'miami': 36944,
#  'fl': 24385,
#  'entertained': 22447,
#  'boyffriend': 14030,
#  'years': 60190,
#  'joe': 32252,
#  'morgan': 37591,
#  'manhattan': 36115,
#  'ny': 39735,
#  'unbelievable': 55057,
#  'removal': 46613,
#  'instructions': 30733,
#  'received': 46145,
#  'advertisement': 9633,
#  'opted': 40645,
#  'receive': 46144,
#  'specials': 50579,
#  'affiliated': 9782,
#  'websites': 58007,
#  'emails': 22127,
#  'opt': 40642,
#  'database': 18701,
#  'optout': 40675,
#  'allow': 10455,
#  '24': 2584,
#  'hours': 28573,
#  'vonolmosatkirekpups': 56866,
#  'thought': 53113,
#  'like': 34775,
#  'freeyankee': 25051,
#  'cgi': 15738,
#  'fy2': 25431,
#  '822slim1': 6740,
#  '822nic1': 6738,
#  '822ppl1': 6739,
#  'daily': 18600,
#  'deals': 18906,
#  'social': 50275,
#  '7c29': 6380,
#  '7c134077': 6378,
#  'events': 22952,
#  'powerhouse': 43489,
#  'gifting': 26191,
#  'program': 43994,
#  'want': 57442,
#  'miss': 37203,
#  'founders': 24856,
#  'major': 36025,
#  'players': 43000,
#  'invitation': 31013,
#  'experts': 23254,
#  'calling': 15086,
#  'way': 57553,
#  'huge': 28752,
#  'cash': 15335,
#  'flow': 24502,
#  'conceived': 17093,
#  'leverage': 34533,
#  '000': 1,
#  '50': 4826,
#  'question': 45344,
#  'wealthy': 57959,
#  'tossing': 53640,
#  'lifeline': 34741,
#  'sake': 48324,
#  'hope': 28490,
#  'grab': 26684,
#  'hold': 28380,
#  'tight': 53223,
#  'ride': 47230,
#  'testimonials': 52870,
#  'hear': 27787,
#  'average': 11919,
#  'people': 42174,
#  've': 56291,
#  'al': 10311,
#  'single': 49764,
#  'mother': 37634,
#  'sure': 51713,
#  'sent': 49080,
#  'pledge': 43027,
#  'got': 26573,
#  'ky': 33826,
#  'didn': 19703,
#  'partner': 41704,
#  'work': 58665,
#  'think': 53074,
#  'decision': 18971,
#  'pick': 42705,
#  'gave': 25787,
#  'leads': 34355,
#  'training': 53830,
#  'ca': 14984,
#  'announcing': 10832,
#  'close': 16466,
#  'sales': 48335,
#  'fax': 23797,
#  'blast': 13525,
#  'immediately': 30131,
#  'entry': 22487,
#  'wait': 57369,
#  '800': 6631,
#  '421': 4238,
#  '6318': 5590,
#  '896': 7272,
#  '6568': 5647,
#  'name__________________________________phone___________________________________________': 38450,
#  'fax_____________________________________email____________________________________________': 23799,
#  'time': 53252,
#  'call_________________________time': 15078,
#  'zone________________________________________': 61439,
#  'message': 36783,
#  'compliance': 17025,
#  'section': 48923,
#  '301': 3259,
#  'paragraph': 41596,
#  '1618': 1488,
#  'transmissions': 53889,
#  'sender': 49049,
#  'stopped': 51174,
#  'cost': 17639,
#  'sending': 49055,
#  'reply': 46706,
#  'address': 9503,
#  'word': 58653,
#  'subject': 51416,
#  'line': 34822,
#  'errors': 22708,
#  'omissions': 40452,
#  'exceptions': 23078,
#  'excluded': 23097,
#  'spam': 50489,
#  'compiled': 16997,
#  'replicate': 46702,
#  'relative': 46507,
#  'seattle': 48893,
#  'marketing': 36230,
#  'gigt': 26203,
#  'turbo': 54227,
#  'team': 52632,
#  'sole': 50332,
#  'purpose': 44449,
#  'communications': 16923,
#  'continued': 17427,
#  'inclusion': 30305,
#  'gracious': 26693,
#  'permission': 42252,
#  'send': 49047,
#  'tesrewinter': 52856,
#  'yahoo': 60064,
#  'deleted': 19150,
#  'wanted': 57443,
#  '14': 1319,
#  'year': 60185,
#  'old': 40392,
#  'fortune': 24826,
#  '500': 4827,
#  'company': 16946,
#  'tremendous': 53966,
#  'rate': 45862,
#  'looking': 35234,
#  'individuals': 30416,
#  'home': 28411,
#  'opportunity': 40623,
#  'excellent': 23071,
#  'income': 30307,
#  'experience': 23238,
#  'train': 53826,
#  'employed': 22207,
#  'career': 15253,
#  'vast': 56211,
#  'opportunities': 40622,
#  'basetel': 12660,
#  'wealthnow': 57958,
#  'energetic': 22333,
#  'self': 49013,
#  'motivated': 37643,
#  'form': 24781,
#  'employement': 22211,
#  'specialist': 50573,
#  'contact': 17375,
#  '4139volw7': 4213,
#  '758dody1425frhm1': 6223,
#  '764smfc8513fcsll40': 6241,
#  'title': 53320,
#  'reliaquote': 46537,
#  'iso': 31283,
#  '8859': 7247,
#  'leftmargin': 34413,
#  'topmargin': 53607,
#  'ffcc99': 24051,
#  'vlink': 56757,
#  'alink': 10407,
#  'ffcc00': 24048,
#  '468': 4369,
#  'bgcolor': 13156,
#  '993366': 7873,
#  '43': 4265,
#  '56': 5048,
#  'theadmanager': 52993,
#  'server': 49164,
#  'asp': 11482,
#  'ad_key': 9455,
#  'yuesbhwakmlk': 60623,
#  'ext': 23322,
#  'target': 52475,
#  '_blank': 8375,
#  'img': 30110,
#  'src': 50814,
#  'banner': 12576,
#  'bannerads': 12578,
#  'images': 30081,
#  'logo6': 35195,
#  'gif': 26184,
#  '120': 1160,
#  '32': 3349,
#  '44': 4292,
#  'nbsp': 38577,
#  '377': 3548,
#  'ffccff': 24052,
#  'headline6': 27762,
#  '220': 2377,
#  '72': 6132,
#  '336699': 3409,
#  '34': 3425,
#  '45': 4324,
#  'tahoma': 52372,
#  'verdana': 56365,
#  'change': 15794,
#  'protect': 44130,
#  'future': 25348,
#  'sufficient': 51559,
#  'middle': 37000,
#  '27': 2729,
#  'freequotes6': 25038,
#  '177': 1587,
#  '3366cc': 3410,
#  '294': 2843,
#  'freequoteform': 25037,
#  'action': 9391,
#  'termlife': 52823,
#  'bin': 13325,
#  'banner_quote_resp': 12577,
#  'method': 36817,
#  'input': 30638,
#  'hidden': 28067,
#  'value': 56158,
#  '51100004022000000321': 4894,
#  'sourceid': 50437,
#  'class': 16324,
#  'hptbcolor': 28621,
#  'ffffff': 24066,
#  'residence': 46837,
#  '65': 5631,
#  'select': 48996,
#  'formscombobox12': 24800,
#  'option': 40665,
#  'selected': 49001,
#  'alabama': 10325,
#  'alaska': 10335,
#  'arizona': 11315,
#  'arkansas': 11318,
#  'california': 15076,
#  'colorado': 16797,
#  'connecticut': 17252,
#  'delaware': 19140,
#  'dc': 18809,
#  'dist': 20064,
#  'columbia': 16812,
#  'florida': 24497,
#  'georgia': 26011,
#  'hawaii': 27629,
#  'idaho': 29505,
#  'illinois': 30040,
#  'indiana': 30383,
#  'iowa': 31071,
#  'kansas': 32871,
#  'kentucky': 33044,
#  'louisiana': 35306,
#  'maine': 36004,
#  'maryland': 36283,
#  'massachusetts': 36299,
#  'michigan': 36962,
#  'minnesota': 37136,
#  'mississippi': 37215,
#  'missouri': 37217,
#  'montana': 37538,
#  'nebraska': 38672,
#  'nevada': 38846,
#  'hampshire': 27448,
#  'jersey': 31970,
#  'mexico': 36833,
#  'york': 60485,
#  'north': 39354,
#  'carolina': 15287,
#  'dakota': 18605,
#  'ohio': 40300,
#  'oklahoma': 40377,
#  'oregon': 40740,
#  'pennsylvania': 42160,
#  'rhode': 47178,
#  'island': 31271,
#  'south': 50445,
#  'tennessee': 52786,
#  'texas': 52882,
#  'utah': 55754,
#  'vermont': 56386,
#  'virginia': 56637,
#  'washington': 57506,
#  'west': 58093,
#  'wisconsin': 58428,
#  'wyoming': 59059,
#  'date': 18711,
#  'birth': 13367,
#  'mm': 37338,
#  'dd': 18856,
#  'yy': 60762,
#  'nowrap': 39439,
#  '01': 172,
#  '03': 279,
#  '04': 315,
#  '05': 345,
#  '06': 372,
#  '07': 396,
#  '09': 476,
#  '11': 1050,
#  '13': 1240,
#  '15': 1391,
#  '16': 1476,
#  '17': 1546,
#  '19': 1680,
#  '20': 2136,
#  '21': 2326,
#  '22': 2376,
#  '23': 2495,
#  '25': 2628,
#  '26': 2677,
#  '28': 2787,
#  '29': 2831,
#  '31': 3316,
#  '33': 3386,
#  '36': 3487,
#  '37': 3527,
#  '38': 3556,
#  '39': 3580,
#  '40': 4138,
#  '41': 4199,
#  '42': 4235,
#  '46': 4354,
#  '47': 4380,
#  '48': 4412,
#  '49': 4444,
#  '51': 4891,
#  '52': 4925,
#  '53': 4956,
#  '54': 4981,
#  '55': 5009,
#  '57': 5076,
#  '58': 5091,
#  '59': 5115,
#  '61': 5541,
#  '62': 5565,
#  '63': 5587,
#  '64': 5605,
#  '67': 5700,
#  '68': 5718,
#  '69': 5739,
#  '73': 6153,
#  '74': 6176,
#  '75': 6203,
#  '76': 6232,
#  '77': 6256,
#  '78': 6282,
#  '79': 6312,
#  '81': 6698,
#  '82': 6726,
#  '83': 6788,
#  '84': 6854,
#  'formsradiobutton1': 24801,
#  'radio': 45714,
#  'male': 36055,
#  'formsradiobutton2': 24802,
#  'female': 23972,
#  'used': 55682,
#  'tobacco': 53498,
#  'products': 43957,
#  'months': 37547,
#  'formsradiobutton4': 24804,
#  'formsradiobutton3': 24803,
#  'formscombobox11': 24799,
#  '100000': 880,
#  '125000': 1191,
#  '125': 1189,
#  '150000': 1395,
#  '150': 1392,
#  '175000': 1578,
#  '175': 1577,
#  '200000': 2139,
#  '200': 2137,
#  '225000': 2426,
#  '225': 2423,
#  '250000': 2631,
#  '250': 2629,
#  '275000': 2763,
#  '275': 2761,
#  '300000': 3251,
#  '300': 3249,
#  '325000': 3366,
#  '325': 3365,
#  '350000': 3458,
#  '350': 3456,
#  '375000': 3545,
#  '375': 3544,
#  '400000': 4141,
#  '400': 4139,
#  '425000': 4250,
#  '425': 4249,
#  '450000': 4326,
#  '450': 4325,
#  '475000': 4394,
#  '475': 4393,
#  '500000': 4830,
#  '550000': 5012,
#  '550': 5010,
#  '600000': 5511,
#  '600': 5509,
#  '650000': 5634,
#  '650': 5632,
#  '700000': 6077,
#  '700': 6076,
#  '750000': 6206,
#  '750': 6204,
#  '800000': 6633,
#  '850000': 6939,
#  '850': 6938,
#  '900000': 7661,
#  '900': 7659,
#  '950000': 7774,
#  '950': 7772,
#  '1000000': 881,
#  '1250000': 1192,
#  '1500000': 1396,
#  '1750000': 1579,
#  '2000000': 2140,
#  '2250000': 2427,
#  '2500000': 2632,
#  '3000000': 3252,
#  '3500000': 3459,
#  '4000000': 4142,
#  '4500000': 4327,
#  '5000000': 4831,
#  '6000000': 5512,
#  '7000000': 6078,
#  '8000000': 6634,
#  '9000000': 7662,
#  '10000000': 882,
#  '11000000': 1053,
#  '12000000': 1163,
#  '13000000': 1243,
#  '14000000': 1322,
#  '15000000': 1397,
#  'need': 38690,
#  'formscombobox10': 24798,
#  'plan': 42961,
#  'formsbutton1': 24797,
#  'submit': 51435,
#  'submitbutton': 51436,
#  'photo6': 42634,
#  'jpg': 32356,
#  '210': 2327,
#  '173': 1568,
#  '217': 2356,
#  'div': 20120,
#  'makes': 36041,
#  'easy': 21555,
#  'instantly': 30717,
#  'quotes': 45398,
#  'highly': 28089,
#  'rated': 45863,
#  '106': 1012,
#  '70percent6': 6105,
#  '131': 1247,
#  'ffcc33': 24049,
#  'today': 53505,
#  '0000ff': 20,
#  'copyright': 17562,
#  '2001': 2143,
#  'rights': 47257,
#  'reserved': 46827,
#  'admanmail': 9549,
#  'hspace': 28690,
#  'vspace': 56993,
#  'alt': 10502,
#  'receiving': 46150,
#  'mailing': 35975,
#  'sendgreatoffers': 49053,
#  'subscribed': 51452,
#  'jm': 32170,
#  'netnoteinc': 38814,
#  'unsubscribe': 55428,
#  'em': 22097,
#  'sgo': 49301,
#  'include': 30301,
#  'unsubscribed': 55430,
#  'correspondence': 17617,
#  'services': 49171,
#  'directed': 19828,
#  'tired': 53307,
#  'bull': 14487,
#  'stop': 51169,
#  'losing': 35283,
#  'real': 46055,
#  'maker': 36039,
#  'big': 13272,
#  'boys': 14033,
#  'drive': 20944,
#  'doorstep': 20456,
#  'short': 49516,
#  'period': 42217,
#  'print': 43835,
#  'successleads': 51517,
#  'firemail': 24291,
#  'telephone': 52732,
#  'number': 39612,
#  'responding': 46892,
#  '499': 4462,
#  '99': 7865,
#  'name___________________________________': 38445,
#  'phone___________________________________': 42623,
#  'fax_____________________________________': 23798,
#  'email___________________________________': 22121,
#  'dear': 18910,
#  'ricardo1': 47207,
#  'red': 46254,
#  'effective': 21794,
#  'direct': 19827,
#  'advertising': 9638,
#  'blue': 13643,
#  'promote': 44049,
#  'business': 14567,
#  'low': 35325,
#  'addresses': 9512,
#  '44c300': 4316,
#  'maximize': 36379,
#  '309': 3284,
#  '407': 4171,
#  '7378': 6165,
#  'consultant': 17358,
#  'discuss': 19951,
#  'needs': 38698,
#  '___________________________________________________________________': 8331,
#  '_______________________________________________________________': 8327,
#  '________________________________________________________________': 8328,
#  'city': 16194,
#  '_____________________________________________________________________': 8332,
#  'phone': 42621,
#  '__________________________________________________________________': 8330,
#  '_______________________________________________________': 8320,
#  '___________________________________________________________________________': 8336,
#  'comments': 16880,
#  'details': 19425,
#  'pricing': 43806,
#  'market': 36226,
#  '247': 2604,
#  'po1': 43172,
#  'kj': 33295,
#  '_8j7bjk9': 8288,
#  'tg0bk5nkiys5': 52941,
#  'cellular': 15619,
#  'accessories': 9240,
#  'wholesale': 58243,
#  'prices': 43803,
#  '202': 2261,
#  '101': 915,
#  '163': 1498,
#  'merchant': 36754,
#  'hands': 27473,
#  'ear': 21524,
#  'buds': 14437,
#  'holsters': 28406,
#  '98': 7837,
#  'booster': 13909,
#  'antennas': 10883,
#  'cases': 15333,
#  'car': 15225,
#  'chargers': 15839,
#  'plates': 42987,
#  'lithium': 34941,
#  'ion': 31056,
#  'batteries': 12702,
#  '94': 7752,
#  'nokia': 39282,
#  'motorola': 37656,
#  'lg': 34584,
#  'nextel': 38923,
#  'samsung': 48381,
#  'qualcomm': 45288,
#  'ericsson': 22673,
#  'audiovox': 11770,
#  'phones': 42626,
#  'assistance': 11539,
#  '732': 6155,
#  '751': 6213,
#  '1457': 1355,
#  'mailings': 35977,
#  'request': 46771,
#  'removemenow68994': 46620,
#  'thank': 52975,
#  'super': 51646,
#  'free4pornlovers': 25015,
#  'simply': 49733,
#  'amateur': 10555,
#  '990000': 7867,
#  '660066': 5659,
#  '9933ff': 7874,
#  'girl': 26234,
#  'door': 20452,
#  'tour': 53667,
#  'ff0099': 24030,
#  'photos': 42647,
#  'sneeky': 50208,
#  'nude': 39596,
#  'exibitionists': 23164,
#  'cheating': 15893,
#  'wives': 58460,
#  'girlfriends': 26236,
#  'pl': 42940,
#  'cell': 15605,
#  'spacer': 50477,
#  '185': 1637,
#  'rowspan': 47662,
#  'qbfuiexorxkl': 44830,
#  '168': 1525,
#  '143': 1341,
#  '181': 1621,
#  'htmlemails': 28722,
#  't193no_option_01': 52126,
#  't193no_option_02': 52127,
#  't193no_option_03': 52128,
#  't193no_option_04': 52129,
#  't193no_option_05': 52130,
#  't193no_option_06': 52131,
#  '115': 1085,
#  't193no_option_07': 52132,
#  '154': 1430,
#  't193no_option_08': 52133,
#  't193no_option_09': 52134,
#  't193no_option_10': 52135,
#  't193no_option_11': 52136,
#  't193no_option_12': 52137,
#  't193no_option_13': 52138,
#  't193no_option_14': 52139,
#  '265': 2690,
#  'simplywireless': 49734,
#  'swdotcomlogo1': 51857,
#  '273': 2750,
#  'voicestream': 56836,
#  'wireless': 58417,
#  'credit': 17903,
#  'approval': 11141,
#  'activate': 9396,
#  'activation': 9399,
#  'fee': 23934,
#  'applies': 11106,
#  'activations': 9400,
#  'available': 11904,
#  'areas': 11277,
#  'fulfilled': 25268,
#  'authorized': 11835,
#  'dealer': 18902,
#  'site': 49796,
#  ...}

# %%
X_train,X_test,y_train,y_test=train_test_split(all_features,df['CATEGORY'],test_size=0.3,random_state=88)

# %%
classifier=MultinomialNB()
classifier.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
# number of emails classified correctly
num_correct_docs=(y_test ==classifier.predict(X_test)).sum() /y_test.size
num_correct_docs
# Out:
# 0.9711111111111111

# %%
y_test.size
pred=classifier.predict(X_test)

# %%
print(f'The accuracy of the model is {num_correct_docs:.2%}')
# Out:
# The accuracy of the model is 97.11%

# %%
classifier.score(X_test,y_test)
# Out:
# 0.9711111111111111

# %%
recall_score(y_test,pred)
# Out:
# 0.8461538461538461

# %%
f1_score(y_test,pred)
# Out:
# 0.9029850746268656

# %%
precision_score(y_test,pred)
# Out:
# 0.968

# %%
example = ['get viagra for free now!', 
          'need a mortgage? Reply to arrange a call with a specialist and get a quote', 
          'Could you please help me with the project for tomorrow?', 
          'Hello Jonathan, how about a game of golf tomorrow?', 
          'Ski jumping is a winter sport in which competitors aim to achieve the longest jump after descending from a specially designed ramp on their skis. Along with jump length, competitor\'s style and other factors affect the final score. Ski jumping was first contested in Norway in the late 19th century, and later spread through Europe and North America in the early 20th century. Along with cross-country skiing, it constitutes the traditional group of Nordic skiing disciplines.'
          ]

# %%
mess_mat=vectorizer.transform(example)

# %%
prediction=classifier.predict(mess_mat)

# %%
prediction
# Out:
# array([1, 1, 0, 0, 0], dtype=int64)
